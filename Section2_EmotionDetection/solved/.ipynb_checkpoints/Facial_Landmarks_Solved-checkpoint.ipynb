# %% [markdown]
# ### 1. Testing the development environment

# %%
import cv2
import numpy as np
import dlib

# Checking the OpenCV version
print("OpenCV version", cv2.__version__)

# Checking the Numpy version
print("Numpy version", np.__version__)

# Checking the dlib version
print("Dlib version", dlib.__version__)
# Out:
# OpenCV version 3.1.0
# Numpy version 1.13.1
# Dlib version 19.6.1

# %% [markdown]
# ### 2. Detecting Faces

# %%
import os
import dlib
import cv2
import numpy as np
import glob
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %matplotlib inline 

PATH = os.path.join("..","images","faces","*.jpg")

def drawBB(image, bound):
    image = image.copy() 
    pt1 = ( bound.left(),bound.top())
    pt2 = ( bound.right(), bound.bottom())
    return cv2.rectangle(image, pt1, pt2, (0,255,0), 3)       

detector = dlib.get_frontal_face_detector()

for image in glob.glob(PATH):
   
    im = mpimg.imread(image)
    
    dets = detector(im)
    
    print("Number of faces detected - {0}".format(len(dets)))
    print(image)
    for k, d in enumerate(dets):
            print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
                k, d.left(), d.top(), d.right(), d.bottom()))
            im = drawBB(im,d)
    
    plt.imshow(im)
    plt.xticks([]), plt.yticks([])
    plt.show()
# Out:
# Number of faces detected - 1
# ../images/faces/Dyane_Johnson.jpg
# Detection 0: Left: 66 Top: 113 Right: 281 Bottom: 328
# Number of faces detected - 1
# ../images/faces/Emma_Watson.jpg
# Detection 0: Left: 732 Top: 237 Right: 1178 Bottom: 683
# Number of faces detected - 1
# ../images/faces/Enrique_Iglesias.jpg
# Detection 0: Left: 189 Top: 134 Right: 314 Bottom: 259
# Number of faces detected - 1
# ../images/faces/Justin_Timberlake.jpg
# Detection 0: Left: 161 Top: 42 Right: 376 Bottom: 257
# Number of faces detected - 1
# ../images/faces/Katy_Perry.jpg
# Detection 0: Left: 520 Top: 90 Right: 735 Bottom: 305
# Number of faces detected - 1
# ../images/faces/Shakira.jpg
# Detection 0: Left: 452 Top: 194 Right: 710 Bottom: 452
# Number of faces detected - 1
# ../images/faces/taylor_swift.jpg
# Detection 0: Left: 79 Top: 65 Right: 203 Bottom: 189
# Number of faces detected - 1
# ../images/faces/Will_Smith.jpg
# Detection 0: Left: 106 Top: 285 Right: 641 Bottom: 820

# %% [markdown]
# ### 3.  Detecting Facial Landmarks

# %%
# Using dlib to detect the faces in an image

import cv2
import dlib
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
from collections import OrderedDict

# %matplotlib inline 

PATH = os.path.join("..","..","dependencies")
FILE_NAME = "shape_predictor_68_face_landmarks.dat"

IMAGE_PATH = os.path.join("..","images","faces","Justin_Timberlake.jpg")

predictor = dlib.shape_predictor(os.path.join(PATH,FILE_NAME))

# define a dictionary that maps the indexes of the facial
# landmarks to specific face regions
FACIAL_LANDMARKS_IDXS = OrderedDict([
    ("mouth", (48, 68)),
    ("right_eyebrow", (17, 22)),
    ("left_eyebrow", (22, 27)),
    ("right_eye", (36, 42)),
    ("left_eye", (42, 48)),
    ("nose", (27, 36)),
    ("jaw", (0, 17))
])

def shape_to_np(shape, dtype="int"):
    # initialize the list of (x, y)-coordinates
    coords = np.zeros((68, 2), dtype=dtype)

    # loop over the 68 facial landmarks and convert them
    # to a 2-tuple of (x, y)-coordinates
    for i in range(0, 68):
        coords[i] = (shape.part(i).x, shape.part(i).y)

    # return the list of (x, y)-coordinates
    return coords


def draw_bb(image, bound):
    image = image.copy() 
    
    pt1 = ( bound.left(), bound.top())
    pt2 = ( bound.right(), bound.bottom())    
    
    return cv2.rectangle(image, pt1, pt2, (0,255,0), thickness=1, lineType=8, shift=0)       


detector = dlib.get_frontal_face_detector()

im  =  mpimg.imread(IMAGE_PATH) # this is the input image

oim = im.copy()

dets = detector(im)

print("Number of faces detected - {0}".format(len(dets)))

for k, d in enumerate(dets):
        print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
            k, d.left(), d.top(), d.right(), d.bottom()))
        
        im = draw_bb(im,d)
        
        gray = cv2.cvtColor(im,cv2.COLOR_RGB2GRAY)     
        
        shape = predictor(gray, d)
        
        shape = shape_to_np(shape)
        
        # show the face number
        cv2.putText(im, "Face #{}".format(k + 1), (d.left() - 10, d.top() - 10),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        for (x, y) in shape:
                cv2.circle(im, (x, y), 1, (0, 0, 255), -1)
        
fig = plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')

plt.subplot(211)
plt.imshow(oim)
plt.xticks([]), plt.yticks([])


plt.subplot(212)
plt.imshow(im)
plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# Number of faces detected - 1
# Detection 0: Left: 161 Top: 42 Right: 376 Bottom: 257

# %% [markdown]
# ### 4.  Recognizing Faces - Celebrities

# %% [markdown]
# #### Face Recognition Indexer

# %%
import os
import dlib
import matplotlib.image as mpimg

def face_feature(image):
    """
    Given a image, returns a list of the detected faces features using the dlib compute_face_descriptor function
    :param face_image : Image of the face
    :return : List of image features
    """ 
    dets = detector(image)
    
    d = [img_chip for img_chip in dets] 
    
    if len(d) == 0:
        return False,None
    else:
        d = d[0] # since the image dataset used for indexing is confirmed to have only a single image
        
        im = draw_bb(image,d)

        gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)     

        sp = predictor(gray, d)

        shape = shape_to_np(sp)

        face_descriptor = facerec.compute_face_descriptor(image, sp)
        
        return True,face_descriptor

    
def face_distance(face_encodings, face_to_compare):
    """
    Given a list of face encodings, compare them to a known face encoding and get a euclidean distance
    for each comparison face. The distance tells you how similar the faces are.
    :param faces: List of face encodings to compare
    :param face_to_compare: A face encoding to compare against
    :return: A numpy ndarray with the distance for each face in the same order as the 'faces' array
    """
    if len(face_encodings) == 0:
        return np.empty((0))

    return np.linalg.norm(face_encodings - face_to_compare, axis=1)


FACE_DEC_MODEL_PATH = os.path.join("..","..","dependencies","shape_predictor_68_face_landmarks.dat")
FACE_REC_MODEL_PATH = os.path.join("..","..","dependencies","dlib_face_recognition_resnet_model_v1 2.dat")
IMAGES_PATH = os.path.join("..","images","lfw","*","*.jpg")

predictor = dlib.shape_predictor(FACE_DEC_MODEL_PATH)
facerec   = dlib.face_recognition_model_v1(FACE_REC_MODEL_PATH)
detector  = dlib.get_frontal_face_detector()

count = 0

features = []
labels = []

for image in glob.glob(IMAGES_PATH):
    
    KEY = image.split("/")[-2]
    
    im = mpimg.imread(image)
    
    print("Indexing %s" % image)
    
    success,feat = face_feature(im)
    
    if success:
       
        features.append(feat)

        labels.append(KEY)

        count+=1

print("Total Faces Indexed", count)
# Out:
# Indexing ../images/lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg
# Indexing ../images/lfw/Aaron_Guiel/Aaron_Guiel_0001.jpg
# Indexing ../images/lfw/Aaron_Patterson/Aaron_Patterson_0001.jpg
# Indexing ../images/lfw/Aaron_Peirsol/Aaron_Peirsol_0001.jpg
# Indexing ../images/lfw/Aaron_Peirsol/Aaron_Peirsol_0002.jpg
# Indexing ../images/lfw/Aaron_Peirsol/Aaron_Peirsol_0003.jpg
# Indexing ../images/lfw/Aaron_Peirsol/Aaron_Peirsol_0004.jpg
# Indexing ../images/lfw/Aaron_Pena/Aaron_Pena_0001.jpg
# Indexing ../images/lfw/Aaron_Sorkin/Aaron_Sorkin_0001.jpg
# Indexing ../images/lfw/Aaron_Sorkin/Aaron_Sorkin_0002.jpg
# Indexing ../images/lfw/Aaron_Tippin/Aaron_Tippin_0001.jpg
# Indexing ../images/lfw/Abba_Eban/Abba_Eban_0001.jpg
# Indexing ../images/lfw/Abbas_Kiarostami/Abbas_Kiarostami_0001.jpg
# Indexing ../images/lfw/Abdel_Aziz_Al-Hakim/Abdel_Aziz_Al-Hakim_0001.jpg
# Indexing ../images/lfw/Abdel_Madi_Shabneh/Abdel_Madi_Shabneh_0001.jpg
# Indexing ../images/lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0001.jpg
# Indexing ../images/lfw/Abdel_Nasser_Assidi/Abdel_Nasser_Assidi_0002.jpg
# Indexing ../images/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0001.jpg
# Indexing ../images/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0002.jpg
# Indexing ../images/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0003.jpg
# Indexing ../images/lfw/Abdoulaye_Wade/Abdoulaye_Wade_0004.jpg
# Indexing ../images/lfw/Abdul_Majeed_Shobokshi/Abdul_Majeed_Shobokshi_0001.jpg
# Indexing ../images/lfw/Abdul_Rahman/Abdul_Rahman_0001.jpg
# Indexing ../images/lfw/Abdulaziz_Kamilov/Abdulaziz_Kamilov_0001.jpg
# Indexing ../images/lfw/Abdullah/Abdullah_0001.jpg
# Indexing ../images/lfw/Abdullah/Abdullah_0002.jpg
# Indexing ../images/lfw/Abdullah/Abdullah_0003.jpg
# Indexing ../images/lfw/Abdullah/Abdullah_0004.jpg
# Indexing ../images/lfw/Abdullah_Ahmad_Badawi/Abdullah_Ahmad_Badawi_0001.jpg
# Indexing ../images/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0001.jpg
# Indexing ../images/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0002.jpg
# Indexing ../images/lfw/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0003.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0001.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0002.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0003.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0004.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0005.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0006.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0007.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0008.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0009.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0010.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0011.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0012.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0013.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0014.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0015.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0016.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0017.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0018.jpg
# Indexing ../images/lfw/Abdullah_Gul/Abdullah_Gul_0019.jpg
# Indexing ../images/lfw/Abdullah_Nasseef/Abdullah_Nasseef_0001.jpg
# Indexing ../images/lfw/Abdullatif_Sener/Abdullatif_Sener_0001.jpg
# Indexing ../images/lfw/Abdullatif_Sener/Abdullatif_Sener_0002.jpg
# Indexing ../images/lfw/Abel_Aguilar/Abel_Aguilar_0001.jpg
# Indexing ../images/lfw/Abel_Pacheco/Abel_Pacheco_0001.jpg
# Indexing ../images/lfw/Abel_Pacheco/Abel_Pacheco_0002.jpg
# Indexing ../images/lfw/Abel_Pacheco/Abel_Pacheco_0003.jpg
# Indexing ../images/lfw/Abel_Pacheco/Abel_Pacheco_0004.jpg
# Indexing ../images/lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0001.jpg
# Indexing ../images/lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0002.jpg
# Indexing ../images/lfw/Abid_Hamid_Mahmud_Al-Tikriti/Abid_Hamid_Mahmud_Al-Tikriti_0003.jpg
# Indexing ../images/lfw/Abner_Martinez/Abner_Martinez_0001.jpg
# Indexing ../images/lfw/Abraham_Foxman/Abraham_Foxman_0001.jpg
# Indexing ../images/lfw/Aby_Har-Even/Aby_Har-Even_0001.jpg
# Indexing ../images/lfw/Adam_Ant/Adam_Ant_0001.jpg
# Indexing ../images/lfw/Adam_Freier/Adam_Freier_0001.jpg
# Indexing ../images/lfw/Adam_Herbert/Adam_Herbert_0001.jpg
# Indexing ../images/lfw/Adam_Kennedy/Adam_Kennedy_0001.jpg
# Indexing ../images/lfw/Adam_Mair/Adam_Mair_0001.jpg
# Indexing ../images/lfw/Adam_Rich/Adam_Rich_0001.jpg
# Indexing ../images/lfw/Adam_Sandler/Adam_Sandler_0001.jpg
# Indexing ../images/lfw/Adam_Sandler/Adam_Sandler_0002.jpg
# Indexing ../images/lfw/Adam_Sandler/Adam_Sandler_0003.jpg
# Indexing ../images/lfw/Adam_Sandler/Adam_Sandler_0004.jpg
# Indexing ../images/lfw/Adam_Scott/Adam_Scott_0001.jpg
# Indexing ../images/lfw/Adam_Scott/Adam_Scott_0002.jpg
# Indexing ../images/lfw/Adel_Al-Jubeir/Adel_Al-Jubeir_0001.jpg
# Indexing ../images/lfw/Adel_Al-Jubeir/Adel_Al-Jubeir_0002.jpg
# Indexing ../images/lfw/Adel_Al-Jubeir/Adel_Al-Jubeir_0003.jpg
# Indexing ../images/lfw/Adelina_Avila/Adelina_Avila_0001.jpg
# Indexing ../images/lfw/Adisai_Bodharamik/Adisai_Bodharamik_0001.jpg
# Indexing ../images/lfw/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0001.jpg
# Indexing ../images/lfw/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0002.jpg
# Indexing ../images/lfw/Adolfo_Aguilar_Zinser/Adolfo_Aguilar_Zinser_0003.jpg
# Indexing ../images/lfw/Adolfo_Rodriguez_Saa/Adolfo_Rodriguez_Saa_0001.jpg
# Indexing ../images/lfw/Adolfo_Rodriguez_Saa/Adolfo_Rodriguez_Saa_0002.jpg
# Indexing ../images/lfw/Adoor_Gopalakarishnan/Adoor_Gopalakarishnan_0001.jpg
# Indexing ../images/lfw/Adrian_Annus/Adrian_Annus_0001.jpg
# Indexing ../images/lfw/Adrian_Fernandez/Adrian_Fernandez_0001.jpg
# Indexing ../images/lfw/Adrian_McPherson/Adrian_McPherson_0001.jpg
# Indexing ../images/lfw/Adrian_McPherson/Adrian_McPherson_0002.jpg
# Indexing ../images/lfw/Adrian_Murrell/Adrian_Murrell_0001.jpg
# Indexing ../images/lfw/Adrian_Nastase/Adrian_Nastase_0001.jpg
# Indexing ../images/lfw/Adrian_Nastase/Adrian_Nastase_0002.jpg
# Indexing ../images/lfw/Adriana_Lima/Adriana_Lima_0001.jpg
# Indexing ../images/lfw/Adriana_Perez_Navarro/Adriana_Perez_Navarro_0001.jpg
# Indexing ../images/lfw/Adrianna_Zuzic/Adrianna_Zuzic_0001.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0001.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0002.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0003.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0004.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0005.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0006.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0007.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0008.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0009.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0010.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0011.jpg
# Indexing ../images/lfw/Adrien_Brody/Adrien_Brody_0012.jpg
# Indexing ../images/lfw/Afton_Smith/Afton_Smith_0001.jpg
# Indexing ../images/lfw/Agbani_Darego/Agbani_Darego_0001.jpg
# Indexing ../images/lfw/Agnelo_Queiroz/Agnelo_Queiroz_0001.jpg
# Indexing ../images/lfw/Agnes_Bruckner/Agnes_Bruckner_0001.jpg
# Indexing ../images/lfw/Ahmad_Jbarah/Ahmad_Jbarah_0001.jpg
# Indexing ../images/lfw/Ahmad_Masood/Ahmad_Masood_0001.jpg
# Indexing ../images/lfw/Ahmad_Masood/Ahmad_Masood_0002.jpg
# Indexing ../images/lfw/Ahmed_Ahmed/Ahmed_Ahmed_0001.jpg
# Indexing ../images/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0001.jpg
# Indexing ../images/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0002.jpg
# Indexing ../images/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0003.jpg
# Indexing ../images/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0004.jpg
# Indexing ../images/lfw/Ahmed_Chalabi/Ahmed_Chalabi_0005.jpg
# Indexing ../images/lfw/Ahmed_Ghazi/Ahmed_Ghazi_0001.jpg
# Indexing ../images/lfw/Ahmed_Ibrahim_Bilal/Ahmed_Ibrahim_Bilal_0001.jpg
# Indexing ../images/lfw/Ahmed_Lopez/Ahmed_Lopez_0001.jpg
# Indexing ../images/lfw/Ahmed_Qureia/Ahmed_Qureia_0001.jpg
# Indexing ../images/lfw/Ahmet_Demir/Ahmet_Demir_0001.jpg
# Indexing ../images/lfw/Ahmet_Necdet_Sezer/Ahmet_Necdet_Sezer_0001.jpg
# Indexing ../images/lfw/Ahmet_Necdet_Sezer/Ahmet_Necdet_Sezer_0002.jpg
# Indexing ../images/lfw/Ai_Sugiyama/Ai_Sugiyama_0001.jpg
# Indexing ../images/lfw/Ai_Sugiyama/Ai_Sugiyama_0002.jpg
# Indexing ../images/lfw/Ai_Sugiyama/Ai_Sugiyama_0003.jpg
# Indexing ../images/lfw/Ai_Sugiyama/Ai_Sugiyama_0004.jpg
# Indexing ../images/lfw/Ai_Sugiyama/Ai_Sugiyama_0005.jpg
# Indexing ../images/lfw/Aicha_El_Ouafi/Aicha_El_Ouafi_0001.jpg
# Indexing ../images/lfw/Aicha_El_Ouafi/Aicha_El_Ouafi_0002.jpg
# Indexing ../images/lfw/Aicha_El_Ouafi/Aicha_El_Ouafi_0003.jpg
# Indexing ../images/lfw/Aidan_Quinn/Aidan_Quinn_0001.jpg
# Indexing ../images/lfw/Aileen_Riggin_Soule/Aileen_Riggin_Soule_0001.jpg
# Indexing ../images/lfw/Ain_Seppik/Ain_Seppik_0001.jpg
# Indexing ../images/lfw/Ainsworth_Dyer/Ainsworth_Dyer_0001.jpg
# Indexing ../images/lfw/Aishwarya_Rai/Aishwarya_Rai_0001.jpg
# Indexing ../images/lfw/Aitor_Gonzalez/Aitor_Gonzalez_0001.jpg
# Indexing ../images/lfw/Aitor_Gonzalez/Aitor_Gonzalez_0002.jpg
# Indexing ../images/lfw/Aiysha_Smith/Aiysha_Smith_0001.jpg
# Indexing ../images/lfw/AJ_Cook/AJ_Cook_0001.jpg
# Indexing ../images/lfw/AJ_Lamas/AJ_Lamas_0001.jpg
# Indexing ../images/lfw/Ajit_Agarkar/Ajit_Agarkar_0001.jpg
# Indexing ../images/lfw/Akbar_Al_Baker/Akbar_Al_Baker_0001.jpg
# Indexing ../images/lfw/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0001.jpg
# Indexing ../images/lfw/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0002.jpg
# Indexing ../images/lfw/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0003.jpg
# Indexing ../images/lfw/Akhmed_Zakayev/Akhmed_Zakayev_0001.jpg
# Indexing ../images/lfw/Akhmed_Zakayev/Akhmed_Zakayev_0002.jpg
# Indexing ../images/lfw/Akhmed_Zakayev/Akhmed_Zakayev_0003.jpg
# Indexing ../images/lfw/Akiko_Morigami/Akiko_Morigami_0001.jpg
# Indexing ../images/lfw/Akmal_Taher/Akmal_Taher_0001.jpg
# Indexing ../images/lfw/Al_Cardenas/Al_Cardenas_0001.jpg
# Indexing ../images/lfw/Al_Davis/Al_Davis_0001.jpg
# Indexing ../images/lfw/Al_Davis/Al_Davis_0002.jpg
# Indexing ../images/lfw/Al_Gore/Al_Gore_0001.jpg
# Indexing ../images/lfw/Al_Gore/Al_Gore_0002.jpg
# Indexing ../images/lfw/Al_Gore/Al_Gore_0003.jpg
# Indexing ../images/lfw/Al_Gore/Al_Gore_0004.jpg
# Indexing ../images/lfw/Al_Gore/Al_Gore_0005.jpg
# Indexing ../images/lfw/Al_Gore/Al_Gore_0006.jpg
# Indexing ../images/lfw/Al_Gore/Al_Gore_0007.jpg
# Indexing ../images/lfw/Al_Gore/Al_Gore_0008.jpg
# Indexing ../images/lfw/Al_Leiter/Al_Leiter_0001.jpg
# Indexing ../images/lfw/Al_Pacino/Al_Pacino_0001.jpg
# Indexing ../images/lfw/Al_Pacino/Al_Pacino_0002.jpg
# Indexing ../images/lfw/Al_Pacino/Al_Pacino_0003.jpg
# Indexing ../images/lfw/Al_Sharpton/Al_Sharpton_0001.jpg
# Indexing ../images/lfw/Al_Sharpton/Al_Sharpton_0002.jpg
# Indexing ../images/lfw/Al_Sharpton/Al_Sharpton_0003.jpg
# Indexing ../images/lfw/Al_Sharpton/Al_Sharpton_0004.jpg
# Indexing ../images/lfw/Al_Sharpton/Al_Sharpton_0005.jpg
# Indexing ../images/lfw/Al_Sharpton/Al_Sharpton_0006.jpg
# Indexing ../images/lfw/Al_Sharpton/Al_Sharpton_0007.jpg
# Indexing ../images/lfw/Alain_Cervantes/Alain_Cervantes_0001.jpg
# Indexing ../images/lfw/Alain_Ducasse/Alain_Ducasse_0001.jpg
# Indexing ../images/lfw/Alan_Ball/Alan_Ball_0001.jpg
# Indexing ../images/lfw/Alan_Ball/Alan_Ball_0002.jpg
# Indexing ../images/lfw/Alan_Dershowitz/Alan_Dershowitz_0001.jpg
# Indexing ../images/lfw/Alan_Dreher/Alan_Dreher_0001.jpg
# Indexing ../images/lfw/Alan_Greenspan/Alan_Greenspan_0001.jpg
# Indexing ../images/lfw/Alan_Greenspan/Alan_Greenspan_0002.jpg
# Indexing ../images/lfw/Alan_Greenspan/Alan_Greenspan_0003.jpg
# Indexing ../images/lfw/Alan_Greenspan/Alan_Greenspan_0004.jpg
# Indexing ../images/lfw/Alan_Greenspan/Alan_Greenspan_0005.jpg
# Indexing ../images/lfw/Alan_Greer/Alan_Greer_0001.jpg
# Indexing ../images/lfw/Alan_Jackson/Alan_Jackson_0001.jpg
# Indexing ../images/lfw/Alan_Mulally/Alan_Mulally_0001.jpg
# Indexing ../images/lfw/Alan_Mulally/Alan_Mulally_0002.jpg
# Indexing ../images/lfw/Alan_Stonecipher/Alan_Stonecipher_0001.jpg
# Indexing ../images/lfw/Alan_Tang_Kwong-wing/Alan_Tang_Kwong-wing_0001.jpg
# Indexing ../images/lfw/Alan_Trammell/Alan_Trammell_0001.jpg
# Indexing ../images/lfw/Alan_Zemaitis/Alan_Zemaitis_0001.jpg
# Indexing ../images/lfw/Alanis_Morissette/Alanis_Morissette_0001.jpg
# Indexing ../images/lfw/Alanna_Ubach/Alanna_Ubach_0001.jpg
# Indexing ../images/lfw/Alastair_Campbell/Alastair_Campbell_0001.jpg
# Indexing ../images/lfw/Alastair_Campbell/Alastair_Campbell_0002.jpg
# Indexing ../images/lfw/Alastair_Campbell/Alastair_Campbell_0003.jpg
# Indexing ../images/lfw/Alastair_Campbell/Alastair_Campbell_0004.jpg
# Indexing ../images/lfw/Alastair_Campbell/Alastair_Campbell_0005.jpg
# Indexing ../images/lfw/Alastair_Johnston/Alastair_Johnston_0001.jpg
# Indexing ../images/lfw/Albaro_Recoba/Albaro_Recoba_0001.jpg
# Indexing ../images/lfw/Albert_Brooks/Albert_Brooks_0001.jpg
# Indexing ../images/lfw/Albert_Costa/Albert_Costa_0001.jpg
# Indexing ../images/lfw/Albert_Costa/Albert_Costa_0002.jpg
# Indexing ../images/lfw/Albert_Costa/Albert_Costa_0003.jpg
# Indexing ../images/lfw/Albert_Costa/Albert_Costa_0004.jpg
# Indexing ../images/lfw/Albert_Costa/Albert_Costa_0005.jpg
# Indexing ../images/lfw/Albert_Costa/Albert_Costa_0006.jpg
# Indexing ../images/lfw/Albert_Montanes/Albert_Montanes_0001.jpg
# Indexing ../images/lfw/Albert_Pujols/Albert_Pujols_0001.jpg
# Indexing ../images/lfw/Alberta_Lee/Alberta_Lee_0001.jpg
# Indexing ../images/lfw/Alberto_Acosta/Alberto_Acosta_0001.jpg
# Indexing ../images/lfw/Alberto_Fujimori/Alberto_Fujimori_0001.jpg
# Indexing ../images/lfw/Alberto_Fujimori/Alberto_Fujimori_0002.jpg
# Indexing ../images/lfw/Alberto_Gonzales/Alberto_Gonzales_0001.jpg
# Indexing ../images/lfw/Alberto_Ruiz_Gallardon/Alberto_Ruiz_Gallardon_0001.jpg
# Indexing ../images/lfw/Alberto_Ruiz_Gallardon/Alberto_Ruiz_Gallardon_0002.jpg
# Indexing ../images/lfw/Alberto_Sordi/Alberto_Sordi_0001.jpg
# Indexing ../images/lfw/Albrecht_Mentz/Albrecht_Mentz_0001.jpg
# Indexing ../images/lfw/Albrecht_Mentz/Albrecht_Mentz_0002.jpg
# Indexing ../images/lfw/Aldo_Paredes/Aldo_Paredes_0001.jpg
# Indexing ../images/lfw/Aldo_Paredes/Aldo_Paredes_0002.jpg
# Indexing ../images/lfw/Alec_Baldwin/Alec_Baldwin_0001.jpg
# Indexing ../images/lfw/Alec_Baldwin/Alec_Baldwin_0002.jpg
# Indexing ../images/lfw/Alec_Baldwin/Alec_Baldwin_0003.jpg
# Indexing ../images/lfw/Alec_Baldwin/Alec_Baldwin_0004.jpg
# Indexing ../images/lfw/Alecos_Markides/Alecos_Markides_0001.jpg
# Indexing ../images/lfw/Alejandro_Atchugarry/Alejandro_Atchugarry_0001.jpg
# Indexing ../images/lfw/Alejandro_Atchugarry/Alejandro_Atchugarry_0002.jpg
# Indexing ../images/lfw/Alejandro_Avila/Alejandro_Avila_0001.jpg
# Indexing ../images/lfw/Alejandro_Avila/Alejandro_Avila_0002.jpg
# Indexing ../images/lfw/Alejandro_Avila/Alejandro_Avila_0003.jpg
# Indexing ../images/lfw/Alejandro_Fernandez/Alejandro_Fernandez_0001.jpg
# Indexing ../images/lfw/Alejandro_Gonzalez_Inarritu/Alejandro_Gonzalez_Inarritu_0001.jpg
# Indexing ../images/lfw/Alejandro_Lembo/Alejandro_Lembo_0001.jpg
# Indexing ../images/lfw/Alejandro_Lerner/Alejandro_Lerner_0001.jpg
# Indexing ../images/lfw/Alejandro_Lopez/Alejandro_Lopez_0001.jpg
# Indexing ../images/lfw/Alejandro_Toledo/Alejandro_Toledo_0001.jpg
# Indexing ../images/lfw/Alejandro_Toledo/Alejandro_Toledo_0002.jpg
# Indexing ../images/lfw/Alejandro_Toledo/Alejandro_Toledo_0003.jpg
# Indexing ../images/lfw/Alejandro_Toledo/Alejandro_Toledo_0004.jpg
# Indexing ../images/lfw/Alejandro_Toledo/Alejandro_Toledo_0005.jpg
# Indexing ../images/lfw/Alejandro_Toledo/Alejandro_Toledo_0006.jpg
# Indexing ../images/lfw/Alejandro_Toledo/Alejandro_Toledo_0007.jpg
# Indexing ../images/lfw/Aleksander_Kwasniewski/Aleksander_Kwasniewski_0004.jpg
# Indexing ../images/lfw/Aleksander_Voloshin/Aleksander_Voloshin_0001.jpg
# Indexing ../images/lfw/Alessandra_Cerna/Alessandra_Cerna_0001.jpg
# Indexing ../images/lfw/Alessandro_Nesta/Alessandro_Nesta_0001.jpg
# Indexing ../images/lfw/Alex_Barros/Alex_Barros_0001.jpg
# Indexing ../images/lfw/Alex_Barros/Alex_Barros_0002.jpg
# Indexing ../images/lfw/Alex_Cabrera/Alex_Cabrera_0001.jpg
# Indexing ../images/lfw/Alex_Cejka/Alex_Cejka_0001.jpg
# Indexing ../images/lfw/Alex_Corretja/Alex_Corretja_0001.jpg
# Indexing ../images/lfw/Alex_Ferguson/Alex_Ferguson_0001.jpg
# Indexing ../images/lfw/Alex_Gonzalez/Alex_Gonzalez_0001.jpg
# Indexing ../images/lfw/Alex_Holmes/Alex_Holmes_0001.jpg
# Indexing ../images/lfw/Alex_King/Alex_King_0001.jpg
# Indexing ../images/lfw/Alex_Penelas/Alex_Penelas_0001.jpg
# Indexing ../images/lfw/Alex_Penelas/Alex_Penelas_0002.jpg
# Indexing ../images/lfw/Alex_Popov/Alex_Popov_0001.jpg
# Indexing ../images/lfw/Alex_Sink/Alex_Sink_0001.jpg
# Indexing ../images/lfw/Alex_Sink/Alex_Sink_0002.jpg
# Indexing ../images/lfw/Alex_Sink/Alex_Sink_0003.jpg
# Indexing ../images/lfw/Alex_Wallau/Alex_Wallau_0001.jpg
# Indexing ../images/lfw/Alex_Zanardi/Alex_Zanardi_0001.jpg
# Indexing ../images/lfw/Alexa_Loren/Alexa_Loren_0001.jpg
# Indexing ../images/lfw/Alexa_Vega/Alexa_Vega_0001.jpg
# Indexing ../images/lfw/Alexander_Downer/Alexander_Downer_0001.jpg
# Indexing ../images/lfw/Alexander_Downer/Alexander_Downer_0002.jpg
# Indexing ../images/lfw/Alexander_Downer/Alexander_Downer_0003.jpg
# Indexing ../images/lfw/Alexander_Downer/Alexander_Downer_0004.jpg
# Indexing ../images/lfw/Alexander_Losyukov/Alexander_Losyukov_0001.jpg
# Indexing ../images/lfw/Alexander_Losyukov/Alexander_Losyukov_0002.jpg
# Indexing ../images/lfw/Alexander_Losyukov/Alexander_Losyukov_0003.jpg
# Indexing ../images/lfw/Alexander_Losyukov/Alexander_Losyukov_0004.jpg
# Indexing ../images/lfw/Alexander_Lukashenko/Alexander_Lukashenko_0001.jpg
# Indexing ../images/lfw/Alexander_Payne/Alexander_Payne_0001.jpg
# Indexing ../images/lfw/Alexander_Rumyantsev/Alexander_Rumyantsev_0001.jpg
# Indexing ../images/lfw/Alexander_Rumyantsev/Alexander_Rumyantsev_0002.jpg
# Indexing ../images/lfw/Alexandra_Jackson/Alexandra_Jackson_0001.jpg
# Indexing ../images/lfw/Alexandra_Pelosi/Alexandra_Pelosi_0001.jpg
# Indexing ../images/lfw/Alexandra_Rozovskaya/Alexandra_Rozovskaya_0001.jpg
# Indexing ../images/lfw/Alexandra_Spann/Alexandra_Spann_0001.jpg
# Indexing ../images/lfw/Ali_Naimi/Ali_Naimi_0006.jpg
# Indexing ../images/lfw/Ali_Naimi/Ali_Naimi_0007.jpg
# Indexing ../images/lfw/Ali_Naimi/Ali_Naimi_0008.jpg
# Indexing ../images/lfw/Alice_Fisher/Alice_Fisher_0001.jpg
# Indexing ../images/lfw/Alice_Fisher/Alice_Fisher_0002.jpg
# Indexing ../images/lfw/Alicia_Hollowell/Alicia_Hollowell_0001.jpg
# Indexing ../images/lfw/Alicia_Keys/Alicia_Keys_0001.jpg
# Indexing ../images/lfw/Alicia_Molik/Alicia_Molik_0001.jpg
# Indexing ../images/lfw/Alicia_Silverstone/Alicia_Silverstone_0001.jpg
# Indexing ../images/lfw/Alicia_Silverstone/Alicia_Silverstone_0002.jpg
# Indexing ../images/lfw/Alicia_Witt/Alicia_Witt_0001.jpg
# Indexing ../images/lfw/Alimzhan_Tokhtakhounov/Alimzhan_Tokhtakhounov_0001.jpg
# Indexing ../images/lfw/Alimzhan_Tokhtakhounov/Alimzhan_Tokhtakhounov_0002.jpg
# Indexing ../images/lfw/Alina_Kabaeva/Alina_Kabaeva_0001.jpg
# Indexing ../images/lfw/Aline_Chretien/Aline_Chretien_0001.jpg
# Indexing ../images/lfw/Alisha_Richman/Alisha_Richman_0001.jpg
# Indexing ../images/lfw/Alison_Krauss/Alison_Krauss_0001.jpg
# Indexing ../images/lfw/Alison_Lohman/Alison_Lohman_0001.jpg
# Indexing ../images/lfw/Alison_Lohman/Alison_Lohman_0002.jpg
# Indexing ../images/lfw/Alistair_MacDonald/Alistair_MacDonald_0001.jpg
# Indexing ../images/lfw/Allan_Houston/Allan_Houston_0001.jpg
# Indexing ../images/lfw/Allan_Kemakeza/Allan_Kemakeza_0001.jpg
# Indexing ../images/lfw/Allan_Wagner/Allan_Wagner_0001.jpg
# Indexing ../images/lfw/Allen_Iverson/Allen_Iverson_0001.jpg
# Indexing ../images/lfw/Allen_Iverson/Allen_Iverson_0002.jpg
# Indexing ../images/lfw/Allen_Rock/Allen_Rock_0001.jpg
# Indexing ../images/lfw/Allison_Janney/Allison_Janney_0001.jpg
# Indexing ../images/lfw/Allison_Janney/Allison_Janney_0002.jpg
# Indexing ../images/lfw/Allison_Searing/Allison_Searing_0001.jpg
# Indexing ../images/lfw/Ally_Sheedy/Ally_Sheedy_0001.jpg
# Indexing ../images/lfw/Allyson_Felix/Allyson_Felix_0001.jpg
# Indexing ../images/lfw/Allyson_Felix/Allyson_Felix_0002.jpg
# Indexing ../images/lfw/Allyson_Felix/Allyson_Felix_0003.jpg
# Indexing ../images/lfw/Allyson_Felix/Allyson_Felix_0004.jpg
# Indexing ../images/lfw/Allyson_Felix/Allyson_Felix_0005.jpg
# Indexing ../images/lfw/Alma_Powell/Alma_Powell_0001.jpg
# Indexing ../images/lfw/Almeida_Baptista/Almeida_Baptista_0001.jpg
# Indexing ../images/lfw/Alonzo_Mourning/Alonzo_Mourning_0001.jpg
# Indexing ../images/lfw/Alvaro_Uribe/Alvaro_Uribe_0030.jpg
# Indexing ../images/lfw/Alvaro_Uribe/Alvaro_Uribe_0031.jpg
# Indexing ../images/lfw/Alvaro_Uribe/Alvaro_Uribe_0032.jpg
# Indexing ../images/lfw/Alvaro_Uribe/Alvaro_Uribe_0033.jpg
# Indexing ../images/lfw/Alvaro_Uribe/Alvaro_Uribe_0034.jpg
# Indexing ../images/lfw/Alvaro_Uribe/Alvaro_Uribe_0035.jpg
# Indexing ../images/lfw/Aly_Wagner/Aly_Wagner_0001.jpg
# Indexing ../images/lfw/Alyse_Beaupre/Alyse_Beaupre_0001.jpg
# Indexing ../images/lfw/Alyson_Hannigan/Alyson_Hannigan_0001.jpg
# Indexing ../images/lfw/Amanda_Beard/Amanda_Beard_0001.jpg
# Indexing ../images/lfw/Amanda_Beard/Amanda_Beard_0002.jpg
# Indexing ../images/lfw/Amanda_Bynes/Amanda_Bynes_0001.jpg
# Indexing ../images/lfw/Amanda_Bynes/Amanda_Bynes_0002.jpg
# Indexing ../images/lfw/Amanda_Bynes/Amanda_Bynes_0003.jpg
# Indexing ../images/lfw/Amanda_Bynes/Amanda_Bynes_0004.jpg
# Indexing ../images/lfw/Amanda_Coetzer/Amanda_Coetzer_0001.jpg
# Indexing ../images/lfw/Amanda_Coetzer/Amanda_Coetzer_0002.jpg
# Indexing ../images/lfw/Amanda_Marsh/Amanda_Marsh_0001.jpg
# Indexing ../images/lfw/Amanda_Plumer/Amanda_Plumer_0001.jpg
# Indexing ../images/lfw/Amber_Frey/Amber_Frey_0001.jpg
# Indexing ../images/lfw/Amber_Tamblyn/Amber_Tamblyn_0001.jpg
# Indexing ../images/lfw/Amber_Tamblyn/Amber_Tamblyn_0002.jpg
# Indexing ../images/lfw/Ambrose_Lee/Ambrose_Lee_0001.jpg
# Indexing ../images/lfw/Amelia_Vega/Amelia_Vega_0001.jpg
# Indexing ../images/lfw/Amelia_Vega/Amelia_Vega_0002.jpg
# Indexing ../images/lfw/Amelia_Vega/Amelia_Vega_0003.jpg
# Indexing ../images/lfw/Amelia_Vega/Amelia_Vega_0004.jpg
# Indexing ../images/lfw/Amelia_Vega/Amelia_Vega_0005.jpg
# Indexing ../images/lfw/Amelia_Vega/Amelia_Vega_0006.jpg
# Indexing ../images/lfw/Amelia_Vega/Amelia_Vega_0007.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0001.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0002.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0003.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0004.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0005.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0006.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0007.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0008.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0009.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0010.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0011.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0012.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0013.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0014.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0015.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0016.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0017.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0018.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0019.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0020.jpg
# Indexing ../images/lfw/Amelie_Mauresmo/Amelie_Mauresmo_0021.jpg
# Indexing ../images/lfw/Amer_al-Saadi/Amer_al-Saadi_0001.jpg
# Indexing ../images/lfw/Amer_al-Saadi/Amer_al-Saadi_0002.jpg
# Indexing ../images/lfw/Amer_al-Saadi/Amer_al-Saadi_0003.jpg
# Indexing ../images/lfw/Amer_al-Saadi/Amer_al-Saadi_0004.jpg
# Indexing ../images/lfw/Amporn_Falise/Amporn_Falise_0001.jpg
# Indexing ../images/lfw/Amr_Moussa/Amr_Moussa_0001.jpg
# Indexing ../images/lfw/Amram_Mitzna/Amram_Mitzna_0001.jpg
# Indexing ../images/lfw/Amram_Mitzna/Amram_Mitzna_0002.jpg
# Indexing ../images/lfw/Amy_Brenneman/Amy_Brenneman_0001.jpg
# Indexing ../images/lfw/Amy_Cotton/Amy_Cotton_0001.jpg
# Indexing ../images/lfw/Amy_Gale/Amy_Gale_0001.jpg
# Indexing ../images/lfw/Amy_Pascal/Amy_Pascal_0001.jpg
# Indexing ../images/lfw/Amy_Redford/Amy_Redford_0001.jpg
# Indexing ../images/lfw/Amy_Smart/Amy_Smart_0001.jpg
# Indexing ../images/lfw/Amy_Yasbeck/Amy_Yasbeck_0001.jpg
# Indexing ../images/lfw/Ana_Claudia_Talancon/Ana_Claudia_Talancon_0001.jpg
# Indexing ../images/lfw/Ana_Guevara/Ana_Guevara_0001.jpg
# Indexing ../images/lfw/Ana_Guevara/Ana_Guevara_0002.jpg
# Indexing ../images/lfw/Ana_Guevara/Ana_Guevara_0003.jpg
# Indexing ../images/lfw/Ana_Guevara/Ana_Guevara_0004.jpg
# Indexing ../images/lfw/Ana_Guevara/Ana_Guevara_0005.jpg
# Indexing ../images/lfw/Ana_Guevara/Ana_Guevara_0006.jpg
# Indexing ../images/lfw/Ana_Guevara/Ana_Guevara_0007.jpg
# Indexing ../images/lfw/Ana_Isabel_Sanchez/Ana_Isabel_Sanchez_0001.jpg
# Indexing ../images/lfw/Ana_Palacio/Ana_Palacio_0001.jpg
# Indexing ../images/lfw/Ana_Palacio/Ana_Palacio_0002.jpg
# Indexing ../images/lfw/Ana_Palacio/Ana_Palacio_0003.jpg
# Indexing ../images/lfw/Ana_Palacio/Ana_Palacio_0004.jpg
# Indexing ../images/lfw/Ana_Palacio/Ana_Palacio_0005.jpg
# Indexing ../images/lfw/Ana_Palacio/Ana_Palacio_0006.jpg
# Indexing ../images/lfw/Ana_Palacio/Ana_Palacio_0007.jpg
# Indexing ../images/lfw/Ana_Palacio/Ana_Palacio_0008.jpg
# Indexing ../images/lfw/Ana_Paula_Gerard/Ana_Paula_Gerard_0001.jpg
# Indexing ../images/lfw/Ana_Sebastiao/Ana_Sebastiao_0001.jpg
# Indexing ../images/lfw/Anastasia_Kelesidou/Anastasia_Kelesidou_0001.jpg
# Indexing ../images/lfw/Anastasia_Myskina/Anastasia_Myskina_0001.jpg
# Indexing ../images/lfw/Anastasia_Myskina/Anastasia_Myskina_0002.jpg
# Indexing ../images/lfw/Anastasia_Myskina/Anastasia_Myskina_0003.jpg
# Indexing ../images/lfw/Anatoliy_Kinakh/Anatoliy_Kinakh_0001.jpg
# Indexing ../images/lfw/Anders_Ebbeson/Anders_Ebbeson_0001.jpg
# Indexing ../images/lfw/Anders_Ebbeson/Anders_Ebbeson_0002.jpg
# Indexing ../images/lfw/Anders_Ebbeson/Anders_Ebbeson_0003.jpg
# Indexing ../images/lfw/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0001.jpg
# Indexing ../images/lfw/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0002.jpg
# Indexing ../images/lfw/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0003.jpg
# Indexing ../images/lfw/Anders_Fogh_Rasmussen/Anders_Fogh_Rasmussen_0004.jpg
# Indexing ../images/lfw/Anderson_Varejao/Anderson_Varejao_0001.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0001.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0002.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0003.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0004.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0005.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0006.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0007.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0008.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0009.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0010.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0011.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0012.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0013.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0014.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0015.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0016.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0017.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0018.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0019.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0020.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0021.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0022.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0023.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0024.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0025.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0026.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0027.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0028.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0029.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0030.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0031.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0032.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0033.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0034.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0035.jpg
# Indexing ../images/lfw/Andre_Agassi/Andre_Agassi_0036.jpg
# Indexing ../images/lfw/Andre_Bucher/Andre_Bucher_0001.jpg
# Indexing ../images/lfw/Andre_Lange/Andre_Lange_0001.jpg
# Indexing ../images/lfw/Andre_Smith/Andre_Smith_0001.jpg
# Indexing ../images/lfw/Andre_Techine/Andre_Techine_0001.jpg
# Indexing ../images/lfw/Andrea_Bocelli/Andrea_Bocelli_0001.jpg
# Indexing ../images/lfw/Andrea_De_Cruz/Andrea_De_Cruz_0001.jpg
# Indexing ../images/lfw/Andrea_Kiser/Andrea_Kiser_0001.jpg
# Indexing ../images/lfw/Andrea_Yates/Andrea_Yates_0001.jpg
# Indexing ../images/lfw/Andreas_Vinciguerra/Andreas_Vinciguerra_0001.jpg
# Indexing ../images/lfw/Andrei_Konchalovsky/Andrei_Konchalovsky_0001.jpg
# Indexing ../images/lfw/Andrei_Mikhnevich/Andrei_Mikhnevich_0001.jpg
# Indexing ../images/lfw/Andrei_Mikhnevich/Andrei_Mikhnevich_0002.jpg
# Indexing ../images/lfw/Andrei_Nikolishin/Andrei_Nikolishin_0001.jpg
# Indexing ../images/lfw/Andres_DAlessandro/Andres_DAlessandro_0001.jpg
# Indexing ../images/lfw/Andres_Manuel_Lopez_Obrador/Andres_Manuel_Lopez_Obrador_0001.jpg
# Indexing ../images/lfw/Andres_Pastrana/Andres_Pastrana_0001.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0008.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0009.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0010.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0011.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0012.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0013.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0014.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0015.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0016.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0017.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0018.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0019.jpg
# Indexing ../images/lfw/Angelina_Jolie/Angelina_Jolie_0020.jpg
# Indexing ../images/lfw/Angelo_Genova/Angelo_Genova_0001.jpg
# Indexing ../images/lfw/Angelo_Reyes/Angelo_Reyes_0001.jpg
# Indexing ../images/lfw/Angelo_Reyes/Angelo_Reyes_0002.jpg
# Indexing ../images/lfw/Angelo_Reyes/Angelo_Reyes_0003.jpg
# Indexing ../images/lfw/Angelo_Reyes/Angelo_Reyes_0004.jpg
# Indexing ../images/lfw/Angie_Arzola/Angie_Arzola_0001.jpg
# Indexing ../images/lfw/Angie_Martinez/Angie_Martinez_0001.jpg
# Indexing ../images/lfw/Anibal_Ibarra/Anibal_Ibarra_0001.jpg
# Indexing ../images/lfw/Anibal_Ibarra/Anibal_Ibarra_0002.jpg
# Indexing ../images/lfw/Anibal_Ibarra/Anibal_Ibarra_0003.jpg
# Indexing ../images/lfw/Anil_Ramsook/Anil_Ramsook_0001.jpg
# Indexing ../images/lfw/Anita_DeFrantz/Anita_DeFrantz_0001.jpg
# Indexing ../images/lfw/Anja_Paerson/Anja_Paerson_0001.jpg
# Indexing ../images/lfw/Anjum_Hussain/Anjum_Hussain_0001.jpg
# Indexing ../images/lfw/Ann_Godbehere/Ann_Godbehere_0001.jpg
# Indexing ../images/lfw/Ann_Landers/Ann_Landers_0001.jpg
# Indexing ../images/lfw/Ann_Morgan/Ann_Morgan_0001.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0001.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0002.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0003.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0004.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0005.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0006.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0007.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0008.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0009.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0010.jpg
# Indexing ../images/lfw/Ann_Veneman/Ann_Veneman_0011.jpg
# Indexing ../images/lfw/Anna_Chicherova/Anna_Chicherova_0001.jpg
# Indexing ../images/lfw/Anna_Faris/Anna_Faris_0001.jpg
# Indexing ../images/lfw/Anna_Jones/Anna_Jones_0001.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0001.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0002.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0003.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0004.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0005.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0006.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0007.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0008.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0009.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0010.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0011.jpg
# Indexing ../images/lfw/Anna_Kournikova/Anna_Kournikova_0012.jpg
# Indexing ../images/lfw/Anna_Nicole_Smith/Anna_Nicole_Smith_0001.jpg
# Indexing ../images/lfw/Anna_Nicole_Smith/Anna_Nicole_Smith_0002.jpg
# Indexing ../images/lfw/Anne_Cavers/Anne_Cavers_0001.jpg
# Indexing ../images/lfw/Anne_Donovan/Anne_Donovan_0001.jpg
# Indexing ../images/lfw/Anne_Heche/Anne_Heche_0001.jpg
# Indexing ../images/lfw/Anne_Krueger/Anne_Krueger_0001.jpg
# Indexing ../images/lfw/Anne_Krueger/Anne_Krueger_0002.jpg
# Indexing ../images/lfw/Anne_Krueger/Anne_Krueger_0003.jpg
# Indexing ../images/lfw/Anne_McLellan/Anne_McLellan_0001.jpg
# Indexing ../images/lfw/Anne_McLellan/Anne_McLellan_0002.jpg
# Indexing ../images/lfw/Anne_McLellan/Anne_McLellan_0003.jpg
# Indexing ../images/lfw/Anne_ONeil/Anne_ONeil_0001.jpg
# Indexing ../images/lfw/Anneli_Jaatteenmaki/Anneli_Jaatteenmaki_0001.jpg
# Indexing ../images/lfw/Anneli_Jaatteenmaki/Anneli_Jaatteenmaki_0002.jpg
# Indexing ../images/lfw/Annette_Bening/Annette_Bening_0001.jpg
# Indexing ../images/lfw/Annette_Bening/Annette_Bening_0002.jpg
# Indexing ../images/lfw/Annette_Lu/Annette_Lu_0001.jpg
# Indexing ../images/lfw/Annette_Lu/Annette_Lu_0002.jpg
# Indexing ../images/lfw/Annette_Lu/Annette_Lu_0003.jpg
# Indexing ../images/lfw/Annie-Jeanne_Reynaud/Annie-Jeanne_Reynaud_0001.jpg
# Indexing ../images/lfw/Annie_Chaplin/Annie_Chaplin_0001.jpg
# Indexing ../images/lfw/William_Pryor_Jr/William_Pryor_Jr_0001.jpg
# Indexing ../images/lfw/William_Ragland/William_Ragland_0001.jpg
# Indexing ../images/lfw/William_Rehnquist/William_Rehnquist_0001.jpg
# Indexing ../images/lfw/William_Rehnquist/William_Rehnquist_0002.jpg
# Indexing ../images/lfw/William_Rosenberg/William_Rosenberg_0001.jpg
# Indexing ../images/lfw/William_Shatner/William_Shatner_0001.jpg
# Indexing ../images/lfw/William_Swor/William_Swor_0001.jpg
# Indexing ../images/lfw/William_Umbach/William_Umbach_0001.jpg
# Indexing ../images/lfw/William_Webster/William_Webster_0001.jpg
# Indexing ../images/lfw/Willie_Nelson/Willie_Nelson_0001.jpg
# Indexing ../images/lfw/Willie_Wilson/Willie_Wilson_0001.jpg
# Indexing ../images/lfw/Willis_Roberts/Willis_Roberts_0001.jpg
# Indexing ../images/lfw/Wilma_McNabb/Wilma_McNabb_0001.jpg
# Indexing ../images/lfw/Wilson_Alvarez/Wilson_Alvarez_0001.jpg
# Indexing ../images/lfw/Wilton_Gregory/Wilton_Gregory_0001.jpg
# Indexing ../images/lfw/Wim_Duisenberg/Wim_Duisenberg_0001.jpg
# Indexing ../images/lfw/Win_Aung/Win_Aung_0001.jpg
# Indexing ../images/lfw/Win_Aung/Win_Aung_0002.jpg
# Indexing ../images/lfw/Win_Aung/Win_Aung_0003.jpg
# Indexing ../images/lfw/Win_Aung/Win_Aung_0004.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0001.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0002.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0003.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0004.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0005.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0006.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0007.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0008.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0009.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0010.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0011.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0012.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0013.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0014.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0015.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0016.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0017.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0018.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0019.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0020.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0021.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0022.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0023.jpg
# Indexing ../images/lfw/Winona_Ryder/Winona_Ryder_0024.jpg
# Indexing ../images/lfw/Winston_Churchill/Winston_Churchill_0001.jpg
# Indexing ../images/lfw/Wolfgang_Becker/Wolfgang_Becker_0001.jpg
# Indexing ../images/lfw/Wolfgang_Clement/Wolfgang_Clement_0001.jpg
# Indexing ../images/lfw/Wolfgang_Schneiderhan/Wolfgang_Schneiderhan_0001.jpg
# Indexing ../images/lfw/Wolfgang_Schuessel/Wolfgang_Schuessel_0001.jpg
# Indexing ../images/lfw/Wolfgang_Schuessel/Wolfgang_Schuessel_0002.jpg
# Indexing ../images/lfw/Wolfgang_Schuessel/Wolfgang_Schuessel_0003.jpg
# Indexing ../images/lfw/Wolfgang_Schuessel/Wolfgang_Schuessel_0004.jpg
# Indexing ../images/lfw/Wolfgang_Schwarz/Wolfgang_Schwarz_0001.jpg
# Indexing ../images/lfw/Woodrow_Stanley/Woodrow_Stanley_0001.jpg
# Indexing ../images/lfw/Woody_Allen/Woody_Allen_0001.jpg
# Indexing ../images/lfw/Woody_Allen/Woody_Allen_0002.jpg
# Indexing ../images/lfw/Woody_Allen/Woody_Allen_0003.jpg
# Indexing ../images/lfw/Woody_Allen/Woody_Allen_0004.jpg
# Indexing ../images/lfw/Woody_Allen/Woody_Allen_0005.jpg
# Indexing ../images/lfw/Wu_Peng/Wu_Peng_0001.jpg
# Indexing ../images/lfw/Wu_Yi/Wu_Yi_0001.jpg
# Indexing ../images/lfw/Wu_Yi/Wu_Yi_0002.jpg
# Indexing ../images/lfw/Wu_Yi/Wu_Yi_0003.jpg
# Indexing ../images/lfw/Wycliffe_Grousbeck/Wycliffe_Grousbeck_0001.jpg
# Indexing ../images/lfw/Xanana_Gusmao/Xanana_Gusmao_0001.jpg
# Indexing ../images/lfw/Xanana_Gusmao/Xanana_Gusmao_0002.jpg
# Indexing ../images/lfw/Xanana_Gusmao/Xanana_Gusmao_0003.jpg
# Indexing ../images/lfw/Xanana_Gusmao/Xanana_Gusmao_0004.jpg
# Indexing ../images/lfw/Xanana_Gusmao/Xanana_Gusmao_0005.jpg
# Indexing ../images/lfw/Xavier_Malisse/Xavier_Malisse_0001.jpg
# Indexing ../images/lfw/Xavier_Malisse/Xavier_Malisse_0002.jpg
# Indexing ../images/lfw/Xavier_Malisse/Xavier_Malisse_0003.jpg
# Indexing ../images/lfw/Xavier_Malisse/Xavier_Malisse_0004.jpg
# Indexing ../images/lfw/Xavier_Malisse/Xavier_Malisse_0005.jpg
# Indexing ../images/lfw/Xiang_Huaicheng/Xiang_Huaicheng_0001.jpg
# Indexing ../images/lfw/Xiang_Liu/Xiang_Liu_0001.jpg
# Indexing ../images/lfw/Xiang_Xu/Xiang_Xu_0001.jpg
# Indexing ../images/lfw/Ximena_Bohorquez/Ximena_Bohorquez_0001.jpg
# Indexing ../images/lfw/Yale_Kamisar/Yale_Kamisar_0001.jpg
# Indexing ../images/lfw/Yana_Klochkova/Yana_Klochkova_0001.jpg
# Indexing ../images/lfw/Yang_Hee_Kim/Yang_Hee_Kim_0001.jpg
# Indexing ../images/lfw/Yang_Jianli/Yang_Jianli_0001.jpg
# Indexing ../images/lfw/Yang_Pao-yu/Yang_Pao-yu_0001.jpg
# Indexing ../images/lfw/Yann_Martel/Yann_Martel_0001.jpg
# Indexing ../images/lfw/Yann_Martel/Yann_Martel_0002.jpg
# Indexing ../images/lfw/Yannos_Papantoniou/Yannos_Papantoniou_0001.jpg
# Indexing ../images/lfw/Yao_Ming/Yao_Ming_0001.jpg
# Indexing ../images/lfw/Yao_Ming/Yao_Ming_0002.jpg
# Indexing ../images/lfw/Yao_Ming/Yao_Ming_0003.jpg
# Indexing ../images/lfw/Yao_Ming/Yao_Ming_0004.jpg
# Indexing ../images/lfw/Yao_Ming/Yao_Ming_0005.jpg
# Indexing ../images/lfw/Yao_Ming/Yao_Ming_0006.jpg
# Indexing ../images/lfw/Yao_Ming/Yao_Ming_0007.jpg
# Indexing ../images/lfw/Yao_Ming/Yao_Ming_0008.jpg
# Indexing ../images/lfw/Yasar_Yakis/Yasar_Yakis_0001.jpg
# Indexing ../images/lfw/Yasar_Yakis/Yasar_Yakis_0002.jpg
# Indexing ../images/lfw/Yasar_Yakis/Yasar_Yakis_0003.jpg
# Indexing ../images/lfw/Yasar_Yakis/Yasar_Yakis_0004.jpg
# Indexing ../images/lfw/Yasein_Taher/Yasein_Taher_0001.jpg
# Indexing ../images/lfw/Yashwant_Sinha/Yashwant_Sinha_0001.jpg
# Indexing ../images/lfw/Yashwant_Sinha/Yashwant_Sinha_0002.jpg
# Indexing ../images/lfw/Yashwant_Sinha/Yashwant_Sinha_0003.jpg
# Indexing ../images/lfw/Yashwant_Sinha/Yashwant_Sinha_0004.jpg
# Indexing ../images/lfw/Yashwant_Sinha/Yashwant_Sinha_0005.jpg
# Indexing ../images/lfw/Yashwant_Sinha/Yashwant_Sinha_0006.jpg
# Indexing ../images/lfw/Yashwant_Sinha/Yashwant_Sinha_0007.jpg
# Indexing ../images/lfw/Yasser_Arafat/Yasser_Arafat_0001.jpg
# Indexing ../images/lfw/Yasser_Arafat/Yasser_Arafat_0002.jpg
# Indexing ../images/lfw/Yasser_Arafat/Yasser_Arafat_0003.jpg
# Indexing ../images/lfw/Yasser_Arafat/Yasser_Arafat_0004.jpg
# Indexing ../images/lfw/Yasser_Arafat/Yasser_Arafat_0005.jpg
# Indexing ../images/lfw/Yasser_Arafat/Yasser_Arafat_0006.jpg
# Indexing ../images/lfw/Yasser_Arafat/Yasser_Arafat_0007.jpg
# Indexing ../images/lfw/Yasser_Arafat/Yasser_Arafat_0008.jpg
# Indexing ../images/lfw/Yasushi_Akashi/Yasushi_Akashi_0001.jpg
# Indexing ../images/lfw/Yasushi_Chimura/Yasushi_Chimura_0001.jpg
# Indexing ../images/lfw/Yekaterina_Guseva/Yekaterina_Guseva_0001.jpg
# Indexing ../images/lfw/Yevgeny_Kafelnikov/Yevgeny_Kafelnikov_0001.jpg
# Indexing ../images/lfw/Yevgeny_Kafelnikov/Yevgeny_Kafelnikov_0002.jpg
# Indexing ../images/lfw/Yevgeny_Kafelnikov/Yevgeny_Kafelnikov_0003.jpg
# Indexing ../images/lfw/Yevgeny_Kafelnikov/Yevgeny_Kafelnikov_0004.jpg
# Indexing ../images/lfw/Yingfan_Wang/Yingfan_Wang_0001.jpg
# Indexing ../images/lfw/Yishan_Zhang/Yishan_Zhang_0001.jpg
# Indexing ../images/lfw/Yoelbi_Quesada/Yoelbi_Quesada_0001.jpg
# Indexing ../images/lfw/Yogi_Berra/Yogi_Berra_0001.jpg
# Indexing ../images/lfw/Yoko_Ono/Yoko_Ono_0001.jpg
# Indexing ../images/lfw/Yoko_Ono/Yoko_Ono_0002.jpg
# Indexing ../images/lfw/Yoko_Ono/Yoko_Ono_0003.jpg
# Indexing ../images/lfw/Yoko_Ono/Yoko_Ono_0004.jpg
# Indexing ../images/lfw/Yoko_Ono/Yoko_Ono_0005.jpg
# Indexing ../images/lfw/Yoko_Ono/Yoko_Ono_0006.jpg
# Indexing ../images/lfw/Yolanda_King/Yolanda_King_0001.jpg
# Indexing ../images/lfw/Yoo_Jay-Kun/Yoo_Jay-Kun_0001.jpg
# Indexing ../images/lfw/Yoon_Jeong_Cho/Yoon_Jeong_Cho_0001.jpg
# Indexing ../images/lfw/Yoon_Jin-Sik/Yoon_Jin-Sik_0001.jpg
# Indexing ../images/lfw/Yoon_Won-Sik/Yoon_Won-Sik_0001.jpg
# Indexing ../images/lfw/Yoon_Young-kwan/Yoon_Young-kwan_0001.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0001.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0002.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0003.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0004.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0005.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0006.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0007.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0008.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0009.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0010.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0011.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0012.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0013.jpg
# Indexing ../images/lfw/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0014.jpg
# Indexing ../images/lfw/Yory_Boy_Campas/Yory_Boy_Campas_0001.jpg
# Indexing ../images/lfw/Yoshiyuki_Kamei/Yoshiyuki_Kamei_0001.jpg
# Indexing ../images/lfw/Yossi_Beilin/Yossi_Beilin_0001.jpg
# Indexing ../images/lfw/Yossi_Beilin/Yossi_Beilin_0002.jpg
# Indexing ../images/lfw/Young_Kim/Young_Kim_0001.jpg
# Indexing ../images/lfw/Yu_Shyi-kun/Yu_Shyi-kun_0001.jpg
# Indexing ../images/lfw/Yu_Shyi-kun/Yu_Shyi-kun_0002.jpg
# Indexing ../images/lfw/Yu_Shyi-kun/Yu_Shyi-kun_0003.jpg
# Indexing ../images/lfw/Yu_Shyi-kun/Yu_Shyi-kun_0004.jpg
# Indexing ../images/lfw/Yukiko_Okudo/Yukiko_Okudo_0001.jpg
# Indexing ../images/lfw/Yukiko_Okudo/Yukiko_Okudo_0002.jpg
# Indexing ../images/lfw/Yukio_Hatoyama/Yukio_Hatoyama_0001.jpg
# Indexing ../images/lfw/Yuri_Fedotov/Yuri_Fedotov_0001.jpg
# Indexing ../images/lfw/Yuri_Fedotov/Yuri_Fedotov_0002.jpg
# Indexing ../images/lfw/Yuri_Luzhkov/Yuri_Luzhkov_0001.jpg
# Indexing ../images/lfw/Yuri_Malenchenko/Yuri_Malenchenko_0001.jpg
# Indexing ../images/lfw/Yuri_Malenchenko/Yuri_Malenchenko_0002.jpg
# Indexing ../images/lfw/Yusaku_Miyazato/Yusaku_Miyazato_0001.jpg
# Indexing ../images/lfw/Yusuf_Misbac/Yusuf_Misbac_0001.jpg
# Indexing ../images/lfw/Yuvraj_Singh/Yuvraj_Singh_0001.jpg
# Indexing ../images/lfw/Yves_Brodeur/Yves_Brodeur_0001.jpg
# Indexing ../images/lfw/Zach_Parise/Zach_Parise_0001.jpg
# Indexing ../images/lfw/Zach_Pillar/Zach_Pillar_0001.jpg
# Indexing ../images/lfw/Zach_Safrin/Zach_Safrin_0001.jpg
# Indexing ../images/lfw/Zafarullah_Khan_Jamali/Zafarullah_Khan_Jamali_0001.jpg
# Indexing ../images/lfw/Zafarullah_Khan_Jamali/Zafarullah_Khan_Jamali_0002.jpg
# Indexing ../images/lfw/Zahir_Shah/Zahir_Shah_0001.jpg
# Indexing ../images/lfw/Zaini_Abdullah/Zaini_Abdullah_0001.jpg
# Indexing ../images/lfw/Zakia_Hakki/Zakia_Hakki_0001.jpg
# Indexing ../images/lfw/Zalmay_Khalilzad/Zalmay_Khalilzad_0001.jpg
# Indexing ../images/lfw/Zara_Akhmadova/Zara_Akhmadova_0001.jpg
# Indexing ../images/lfw/Zarai_Toledo/Zarai_Toledo_0001.jpg
# Indexing ../images/lfw/Zarai_Toledo/Zarai_Toledo_0002.jpg
# Indexing ../images/lfw/Zavad_Zarif/Zavad_Zarif_0001.jpg
# Indexing ../images/lfw/Zdravko_Mucic/Zdravko_Mucic_0001.jpg
# Indexing ../images/lfw/Zeljko_Rebraca/Zeljko_Rebraca_0001.jpg
# Indexing ../images/lfw/Zelma_Novelo/Zelma_Novelo_0001.jpg
# Indexing ../images/lfw/Zeng_Qinghong/Zeng_Qinghong_0001.jpg
# Indexing ../images/lfw/Zhang_Wenkang/Zhang_Wenkang_0001.jpg
# Indexing ../images/lfw/Zhang_Wenkang/Zhang_Wenkang_0002.jpg
# Indexing ../images/lfw/Zhang_Yimou/Zhang_Yimou_0001.jpg
# Indexing ../images/lfw/Zhang_Ziyi/Zhang_Ziyi_0001.jpg
# Indexing ../images/lfw/Zhang_Ziyi/Zhang_Ziyi_0002.jpg
# Indexing ../images/lfw/Zhang_Ziyi/Zhang_Ziyi_0003.jpg
# Indexing ../images/lfw/Zhang_Ziyi/Zhang_Ziyi_0004.jpg
# Indexing ../images/lfw/Zhong_Nanshan/Zhong_Nanshan_0001.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0001.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0002.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0003.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0004.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0005.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0006.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0007.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0008.jpg
# Indexing ../images/lfw/Zhu_Rongji/Zhu_Rongji_0009.jpg
# Indexing ../images/lfw/Zico/Zico_0001.jpg
# Indexing ../images/lfw/Zico/Zico_0002.jpg
# Indexing ../images/lfw/Zico/Zico_0003.jpg
# Indexing ../images/lfw/Zinedine_Zidane/Zinedine_Zidane_0001.jpg
# Indexing ../images/lfw/Zinedine_Zidane/Zinedine_Zidane_0002.jpg
# Indexing ../images/lfw/Zinedine_Zidane/Zinedine_Zidane_0003.jpg
# Indexing ../images/lfw/Zinedine_Zidane/Zinedine_Zidane_0004.jpg
# Indexing ../images/lfw/Zinedine_Zidane/Zinedine_Zidane_0005.jpg
# Indexing ../images/lfw/Zinedine_Zidane/Zinedine_Zidane_0006.jpg
# Indexing ../images/lfw/Ziwang_Xu/Ziwang_Xu_0001.jpg
# Indexing ../images/lfw/Zoe_Ball/Zoe_Ball_0001.jpg
# Indexing ../images/lfw/Zoran_Djindjic/Zoran_Djindjic_0001.jpg
# Indexing ../images/lfw/Zoran_Djindjic/Zoran_Djindjic_0002.jpg
# Indexing ../images/lfw/Zoran_Djindjic/Zoran_Djindjic_0003.jpg
# Indexing ../images/lfw/Zoran_Djindjic/Zoran_Djindjic_0004.jpg
# Indexing ../images/lfw/Zorica_Radovic/Zorica_Radovic_0001.jpg
# Indexing ../images/lfw/Zulfiqar_Ahmed/Zulfiqar_Ahmed_0001.jpg
# Indexing ../images/lfw/Zumrati_Juma/Zumrati_Juma_0001.jpg
# Indexing ../images/lfw/Zurab_Tsereteli/Zurab_Tsereteli_0001.jpg
# Indexing ../images/lfw/Zydrunas_Ilgauskas/Zydrunas_Ilgauskas_0001.jpg
# Total Faces Indexed 13178

# %% [markdown]
# In order to be able to recognize and tag celebrtiy faces in the image, we will need to generate the feature vector for every image that the model was trained on.
#
# Next,when we trying to recogize a face, we will check the cosine similarity of faces in the unknown image against a dictionary of **Celebrity Name** mapped to feature vectors, to recognize the faces in the image.
#
# Since, dlib uses the **Labelled Faces in Wild** dataset we will download them locally and generate the index to use in the next step, to accuractely recognize the faces in an image.
#
# **Download Link**
#
# > http://vis-www.cs.umass.edu/lfw/lfw.tgz
#
# Extract the above dataset and build an index of Name with corresponding feature vectors.

# %% [markdown]
# #### Face Recognition Client

# %%
print(np.array(features).shape)
# Out:
# (19, 128)

# %%
# Using dlib to recognize the face based on cosine simularity

import cv2
import dlib
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
from collections import OrderedDict

# %matplotlib inline 

IMAGE_PATH = os.path.join("..","images","faces","Emma_Watson.jpg")
FACE_DEC_MODEL_PATH = os.path.join("..","..","dependencies","shape_predictor_68_face_landmarks.dat")
FACE_REC_MODEL_PATH = os.path.join("..","..","dependencies","dlib_face_recognition_resnet_model_v1 2.dat")

predictor = dlib.shape_predictor(FACE_DEC_MODEL_PATH)
facerec   = dlib.face_recognition_model_v1(FACE_REC_MODEL_PATH)
detector  = dlib.get_frontal_face_detector()

# define a dictionary that maps the indexes of the facial
# landmarks to specific face regions
FACIAL_LANDMARKS_IDXS = OrderedDict([
    ("mouth", (48, 68)),
    ("right_eyebrow", (17, 22)),
    ("left_eyebrow", (22, 27)),
    ("right_eye", (36, 42)),
    ("left_eye", (42, 48)),
    ("nose", (27, 36)),
    ("jaw", (0, 17))
])

def shape_to_np(shape, dtype="int"):
    # initialize the list of (x, y)-coordinates
    coords = np.zeros((68, 2), dtype=dtype)

    # loop over the 68 facial landmarks and convert them
    # to a 2-tuple of (x, y)-coordinates
    for i in range(0, 68):
        coords[i] = (shape.part(i).x, shape.part(i).y)

    # return the list of (x, y)-coordinates
    return coords


def draw_bb(image, bound):
    image = image.copy() 
    
    pt1 = ( bound.left(), bound.top())
    pt2 = ( bound.right(), bound.bottom())    
    
    return cv2.rectangle(image, pt1, pt2, (0,255,0), 3)       


detector = dlib.get_frontal_face_detector()

im  = mpimg.imread(IMAGE_PATH) # this is the input image

dets = detector(im)

print("Number of faces detected - {0}".format(len(dets)))

for k, d in enumerate(dets):
        im = draw_bb(im,d)
        
        gray = cv2.cvtColor(im,cv2.COLOR_RGB2GRAY)     
        
        sp = predictor(gray, d)
        
        shape = shape_to_np(sp)
        
        face_descriptor = np.array(facerec.compute_face_descriptor(im, sp))
    
        LABEL = labels[np.argmin(face_distance(features,face_descriptor), axis=0)]
        
        # show the face number
        cv2.putText(im, LABEL, (d.left() - 10, d.top() - 10),cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)
        
fig = plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')

plt.imshow(im)
plt.xticks([]), plt.yticks([])

plt.show()
